# %%
from ml4tputils.visualize import *
from ml4tputils.recon.tactr import *

# tgtlem = "split_pat"
# tgtlem = "case_split"
# file = "/Users/dehuang/Documents/research/ml4tp/ex/test.dump2"

# tgtlem = "foo"
# file = "/Users/dehuang/Documents/research/ml4tp/ex/do.dump"

# tgtlem = "rewrite_eq_0"
# file = "/Users/dehuang/Documents/research/ml4tp/ex/alg.dump"

# tgtlem = "rewrite_eq_0"
# file = "/Users/dehuang/Documents/research/ml4tp/theorems.dump"

tgtlem = "plus_O_nop"
file = "/Users/dehuang/Documents/research/ml4tp/ex/running.dump"

vis = Visualize(f_display=True, f_jupyter=True, f_verbose=False)
tactr = vis.visualize_lemma(file, tgtlem)

# for _, tacs in tactr.tactics().items():
#     print("HERE")
#     for tac in tacs:
#         print(tac.ftac)
# for edge in tactr.graph.edges():
#     print("SRC", edge[0].gid, "TGT", edge[1].gid)
# print(tactr.graph.out_degree([TacTrNode(5, TacStKind.LIVE)]))

# %%
from ml4tputils.visualize import *
from ml4tputils.recon.tactr import *

# tgtlem = "subset_trans"
# tgtlem = "subset_trans2"
tgtlem = "HilbertS"
# tgtlem = "andb_sym2"
# file = "/Users/dehuang/Documents/research/ml4tp/ex/tutorial.dump"
#tgtlem = "plus_comm"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/foo9.dump"
#tgtlem = "plus_O"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/done.dump"
vis = Visualize(f_display=True, f_jupyter=True, f_verbose=False)
tactr = vis.visualize_lemma(file, tgtlem)

# for _, tacs in tactr.tactics().items():
#     print("HERE")
#     for tac in tacs:
#         print(tac.ftac)
for edge in tactr.graph.edges():
    print("SRC", edge[0].gid, "TGT", edge[1].gid)
# print(tactr.graph.out_degree([TacTrNode(5, TacStKind.LIVE)]))

# %%
from ml4tputils.visualize import *

tgtlem = "rewrite_eq_0"
file = "/Users/dehuang/Documents/research/ml4tp/ml4tputils/ml/rewriter/rewrite/theorems.dump"
#tgtlem = "plus_comm"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/foo9.dump"
#tgtlem = "plus_O"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/done.dump"
vis = Visualize(f_display=True, f_jupyter=True, f_verbose=False)
tactrs = vis.visualize_lemma(file, tgtlem)

# %%
from ml4tputils.visualize import *

tgtlem = "iden_eq_short"
file = "/Users/dehuang/Documents/research/ml4tp/ex/thm1.dump"
#tgtlem = "plus_comm"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/foo9.dump"
#tgtlem = "plus_O"
#file = "/Users/dehuang/Documents/research/ml4tp/ex/done.dump"
vis = Visualize(f_display=True, f_jupyter=True, f_verbose=False)
tactrs = vis.visualize_lemma(file, tgtlem)

# %%
from ml4tputils.visualize import *

# tgtlem = "focal_subgroup_gen"
# tgtlem = "critical_odd"
# tgtlem = "p_elt_gen_normal"
# tgtlem = "chief_stab_sub_Fitting"
# tgtlem = "nG\'G"
# tgtlem = "minnormal_solvable_Fitting_center"
# tgtlem = "minnormal_solvable_abelem"
# tgtlem = "sol_chief_abelem"
tgtlem = "coprime_cent_prod"
file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection1.v.dump"

tgtlem = "FT_Dade_support_disjoint"
file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/PFsection8.v.dump"

# tgtlem = "sQP0Q"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGappendixC.v.dump"

# tgtlem = "Frobenius_Wielandt_fixpoint"
# tgtlem = "odd_prime_sdprod_rfix0"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection3.v.dump"

# tgtlem = "exponent_odd_nil23"
# tgtlem = "pi_Aut_rank2_pgroup"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection4.v.dump"

# tgtlem = "cent_tau1Elem_Msigma"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection13.v.dump"

# tgtlem = "nonabelian_tau2"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection12.v.dump"

# tgtlem = "oU"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/PFsection14.v.dump"

# tgtlem = "narrowJ"
# file = "/Users/dehuang/Documents/research/ml4tp/data/odd-order/BGsection5.v.dump"

vis = Visualize(f_display=True, f_jupyter=True, f_verbose=False)
tactr = vis.visualize_lemma(file, tgtlem)
#print(tactr.bfs_traverse())
print(str(tactr.decoder.decoded[23]))
tactr.visualize_exp_by_key(23)
# Out:
# progress: 0.00% @ compl_of_typeF
# progress: 3.09% @ Frobenius_of_typeF
# progress: 4.55% @ typeF_context
# progress: 11.49% @ of_typeP_sol
# progress: 11.87% @ typeP_cent_compl
# progress: 12.39% @ typeP_cent_core_compl
# progress: 12.96% @ typePF_exclusion
# progress: 15.19% @ of_typeP_compl_conj
# progress: 15.88% @ conj_of_typeP
# progress: 17.23% @ typeP_context
# progress: 21.13% @ FTtypeP_witness
# progress: 21.81% @ of_typeP_conj
# progress: 24.00% @ FTtypeP_neq1
# progress: 24.40% @ compl_of_typeII_IV
# progress: 25.75% @ compl_of_typeII
# progress: 27.74% @ compl_of_typeIII
# progress: 28.80% @ compl_of_typeIV
# progress: 29.86% @ compl_of_typeV
# progress: 30.52% @ typeP_pair_sym
# progress: 31.31% @ FTtypeP_pair_cases
# progress: 34.67% @ typeP_pairW
# progress: 37.46% @ FTcore_facts
# progress: 39.11% @ FTtypeI_II_facts
# progress: 42.18% @ FTsupport_facts
# progress: 45.95% @ norm_FTsuppX
# progress: 47.75% @ norm_FTsupp1
# progress: 47.87% @ norm_FTsupp
# progress: 47.99% @ norm_FTsupp0
# progress: 48.15% @ FTsignalizerJ
# progress: 48.44% @ is_FTsignalizer
# progress: 49.17% @ FT_Dade0_hyp
# progress: 50.94% @ def_FTsignalizer0
# progress: 51.09% @ def_FTsignalizer
# progress: 51.21% @ def_FTsignalizer1
# progress: 51.32% @ def_FTsignalizerF
# progress: 51.45% @ FT_DadeE
# progress: 51.59% @ FT_Dade1E
# progress: 51.73% @ FT_DadeF_E
# progress: 51.88% @ FT_Dade_supportS
# progress: 52.19% @ FT_Dade0_supportE
# progress: 52.38% @ defA
# progress: 52.58% @ FT_Dade_supportE
# progress: 52.71% @ FT_Dade1_supportE
# progress: 52.84% @ FT_DadeF_supportE
# progress: 52.97% @ FT_Dade0_supportJ
# progress: 53.35% @ FT_Dade1_supportJ
# progress: 53.73% @ FT_Dade_supportJ
# progress: 54.11% @ FT_cyclicTI_hyp
# progress: 54.34% @ FTtypeP_pair_witness
# progress: 57.48% @ of_typeP_pair
# progress: 59.55% @ FT_primeTI_hyp
# progress: 60.67% @ FTtypeP_supp0_def
# progress: 61.05% @ FT_Fcore_prime_Dade_def
# progress: 63.96% @ FT_core_prime_Dade_def
# progress: 65.99% @ FTtypeP_cohererence_base_subproof
# progress: 66.19% @ FTtypeP_cohererence_nonreal_subproof
# progress: 66.53% @ FTtypeP_subcoherent
# progress: 66.95% @ FTtypeP_base_ortho
# progress: 67.41% @ FTtypeP_base_TIred
# progress: 67.89% @ coherent_ortho_cycTIiso
# progress: 68.64% @ FTtypeP_coherent_TIred
# progress: 71.64% @ size_red_subseq_seqInd_typeP
# progress: 73.24% @ FTtypeII_ker_TI
# progress: 76.18% @ FT_Dade_support_partition
# progress: 83.81% @ FT_Dade_support_disjoint
# progress: 83.81% @ FT_Dade_support_disjoint
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="16f93026-2053-4b67-929f-229254a7ca61" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16f93026-2053-4b67-929f-229254a7ca61", [{"type": "scatter", "x": [0.09834233618653483, 0.08097237936483502, null, 0.08097237936483502, 0.06255986051065723, null, 0.06255986051065723, 0.013383390633414715, null, 0.06255986051065723, 0.09603597897468434, null, 0.013383390633414715, -0.031034921194137956, null, 0.09603597897468434, 0.11501078800666227, null, 0.09603597897468434, 0.11637788551037437, null, -0.031034921194137956, -0.06775401748452513, null, -0.031034921194137956, -0.07523355045582165, null, -0.06775401748452513, -0.10780764323864854, null, -0.07523355045582165, -0.11902447197850116, null, -0.10780764323864854, -0.10780764323864854, null, -0.10780764323864854, -0.10780764323864854, null, -0.10780764323864854, -0.14939122104948432, null, -0.10780764323864854, -0.14936231028056557, null, -0.10780764323864854, -0.14932249851097312, null, -0.10780764323864854, -0.14927350651731053, null, -0.14939122104948432, -0.19142928732627645, null, -0.14936231028056557, -0.19136863563761727, null, -0.14932249851097312, -0.19129839578761618, null, -0.14927350651731053, -0.1912242615213152, null, -0.11902447197850116, -0.16238282477402455, null, -0.16238282477402455, -0.2012153015394334, null, -0.16238282477402455, -0.20594956562942104, null, -0.2012153015394334, -0.2372142915730517, null, -0.2012153015394334, -0.2438178797114179, null, -0.20594956562942104, -0.24371547798265053, null, -0.20594956562942104, -0.25042574988661587, null, -0.2372142915730517, -0.27411016430399976, null, -0.2438178797114179, -0.2865192960761367, null, -0.27411016430399976, -0.3135535180952854, null, -0.3135535180952854, -0.3135535180952854, null, -0.3135535180952854, -0.34991291233570065, null, -0.3135535180952854, -0.34998990306141503, null, -0.34991291233570065, -0.38685089520190846, null, -0.34998990306141503, -0.386894041259005, null, -0.2865192960761367, -0.32958902043093646, null, -0.32958902043093646, -0.32958902043093646, null, -0.32958902043093646, -0.36959526094701806, null, -0.32958902043093646, -0.3695735572587551, null, -0.32958902043093646, -0.3695375574498125, null, -0.32958902043093646, -0.3733361608201348, null, -0.32958902043093646, -0.3733361608201348, null, -0.36959526094701806, -0.41040276888665406, null, -0.3695735572587551, -0.4103893388510973, null, -0.3695375574498125, -0.410342272093189, null, -0.3733361608201348, -0.4134995925806135, null, -0.3733361608201348, -0.413280168964708, null, -0.3733361608201348, -0.41724223651300113, null, -0.41724223651300113, -0.4602476262539109, null, -0.4602476262539109, -0.5025983411754634, null, -0.4602476262539109, -0.5038896606749234, null, -0.5025983411754634, -0.5462514711931531, null, -0.5038896606749234, -0.547405952193905, null, -0.5038896606749234, -0.5475805695666288, null, -0.547405952193905, -0.5912524589317014, null, -0.5475805695666288, -0.590957955471301, null, -0.5475805695666288, -0.5908290597969021, null, -0.590957955471301, -0.6346041973583205, null, -0.5908290597969021, -0.6346090085046393, null, -0.5908290597969021, -0.6346369248722966, null, -0.6346090085046393, -0.6781451864387, null, -0.6346369248722966, -0.6781420438299672, null, -0.6346369248722966, -0.6780460281108601, null, -0.6781420438299672, -0.7219173452108518, null, -0.6780460281108601, -0.7217564622565569, null, -0.24371547798265053, -0.285028092171041, null, -0.24371547798265053, -0.2817550057192472, null, -0.25042574988661587, -0.28791184567422023, null, -0.25042574988661587, -0.2941352401660277, null, -0.285028092171041, -0.285028092171041, null, -0.285028092171041, -0.285028092171041, null, -0.285028092171041, -0.3279072019854352, null, -0.285028092171041, -0.3279295716931425, null, -0.2817550057192472, -0.2817550057192472, null,  ...
# C(mathcomp.odd_order.BGsection7.minSimple_max_groups, )
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="a75221d6-bacc-4c44-bcaf-fc6c8040ec8f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a75221d6-bacc-4c44-bcaf-fc6c8040ec8f", [{"type": "scatter", "x": [], "y": [], "line": {"width": 0.5, "color": "#888"}, "hoverinfo": null, "mode": "lines"}, {"type": "scatter", "x": [0.0], "y": [0.0], "text": ["Const(mathcomp.odd_order.BGsection7.minSimple_max_groups)"], "mode": "markers", "hoverinfo": "text", "marker": {"showscale": true, "colorscale": "YIGnBu", "reversescale": true, "color": [], "size": 10, "line": {"width": 2}}}], {"title": "<br>Reconstruction of AST C(mathcomp.odd_order.BGsection7.minSimple_max_grou ...", "titlefont": {"size": 16}, "showlegend": false, "hovermode": "closest", "margin": {"b": 20, "l": 5, "r": 5, "t": 40}, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
from ml4tputils.exp_tactr_stats import *

# Feit-Thompson (Odd-order theorem)
stats, unique = load_tactr_stats("log/tactr-build-20.log")
tactr_stats = TacTrStats(stats)
print("Unique const:", unique['const'])
print("Unique inductive:", unique['ind'])
print("Unique constructors:", unique['conid'])
_ = tactr_stats.descrip_tacs()
_ = tactr_stats.descrip_tacsts()
_ = tactr_stats.descrip_term()
_ = tactr_stats.descrip_deadend()

# %%
_ = tactr_stats.gather_have_info()

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

coqexp_hist = tactr_stats.coqexp_hist()
data = [go.Bar(x=[p[0] for p in coqexp_hist], y=[p[1] for p in coqexp_hist])]

layout = go.Layout(
    title='CoqExp Usage (all lemmas)',
    xaxis=dict(
        title='Coq Expression'
    ),
    yaxis=dict(
        title='Usage',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='coqexp-hist')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

hist_sh, maxsize = tactr_stats.coqexp_comp_p('static_sh_comp', f_avg=False, f_trunc=False)
print("Maxsize", maxsize)
data = [go.Bar(x=[k for k, v in hist_sh.items()], y=[v for k, v in hist_sh.items()])]

layout = go.Layout(
    title='CoqExp Computation Static-Share',
    xaxis=dict(
        title='Size of Term'
    ),
    yaxis=dict(
        title='Number of terms',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='coqexp-sh-hist')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

hist_sf, maxsize = tactr_stats.coqexp_comp_p('static_full_comp', f_avg=False, f_trunc=False)
print("Maxsize", maxsize)
data = [go.Bar(x=[k for k, v in hist_sf.items()], y=[v for k, v in hist_sf.items()])]

layout = go.Layout(
    title='CoqExp Computation Static-Full',
    xaxis=dict(
        title='Size'
    ),
    yaxis=dict(
        title='Number',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='coqexp-sf-hist')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

hist_nm, maxsize = tactr_stats.coqexp_comp_p('cbname_comp', f_avg=False, f_trunc=True)
print("Maxsize", maxsize)
data = [go.Bar(x=[k for k, v in hist_nm.items()], y=[v for k, v in hist_nm.items()])]

layout = go.Layout(
    title='CoqExp Computation Call-By-Name',
    xaxis=dict(
        title='Size of Term'
    ),
    yaxis=dict(
        title='Number of Terms',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='coqexp-nm-hist')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

tactic_hist = tactr_stats.avg_hist(f_sort=True)
data = [go.Bar(x=[p[0] for p in tactic_hist], y=[p[1] for p in tactic_hist])]

layout = go.Layout(
    title='Tactic Usage (all lemmas)',
    xaxis=dict(
        title='Tactic'
    ),
    yaxis=dict(
        title='Usage',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='tactic-hist')

# %%
avg_depth_ctx_size = tactr_stats.avg_depth_size(DepthMode.AST_CTX).items()
print(avg_depth_ctx_size)

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

avg_depth_ctx_size = tactr_stats.avg_depth_size(DepthMode.AST_CTX).items()
data = [go.Bar(x=[p[0] for p in avg_depth_ctx_size], y=[p[1] for p in avg_depth_ctx_size])]

layout = go.Layout(
    title='Average Context Size vs. Depth in Tree',
    xaxis=dict(
        title='Depth (proof tree)'
    ),
    yaxis=dict(
        title='Size of context (char-length)',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='average-context-size')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

avg_depth_goal_size = tactr_stats.avg_depth_size(DepthMode.CHAR_GOAL).items()
data = [go.Bar(x=[p[0] for p in avg_depth_goal_size], y=[p[1] for p in avg_depth_goal_size])]

layout = go.Layout(
    title='Average Goal Size vs. Depth in Tree',
    xaxis=dict(
        title='Depth (proof tree)'
    ),
    yaxis=dict(
        title='Size of goal (char-length)',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='average-goal-size')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

avg_depth_astctx_size = tactr_stats.avg_depth_size(DepthMode.AST_CTX).items()
data = [go.Bar(x=[p[0] for p in avg_depth_astctx_size], y=[p[1] for p in avg_depth_astctx_size])]

layout = go.Layout(
    title='Average Context Size vs. Depth in Tree',
    xaxis=dict(
        title='Depth (proof tree)'
    ),
    yaxis=dict(
        title='Size of context (ast-size)',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='average-context-size')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

avg_depth_astgoal_size = tactr_stats.avg_depth_size(DepthMode.AST_GOAL).items()
data = [go.Bar(x=[p[0] for p in avg_depth_astgoal_size], y=[p[1] for p in avg_depth_astgoal_size])]

layout = go.Layout(
    title='Average Goal Size vs. Depth in Tree',
    xaxis=dict(
        title='Depth (proof tree)'
    ),
    yaxis=dict(
        title='Size of context (ast-size)',
    ),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='average-context-size')
